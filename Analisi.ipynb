# %%
import pandas as pd
import pyodbc

# %%
# Connection String
serverName = "datasolve.database.windows.net" 
databaseName = "DataSolveDB"
username = "sqladmin"
password = "AlfaBravo2024"

# %%
# Make the connection to our Server
connection_string = f'DRIVER={{SQL Server}};SERVER='+serverName+';DATABASE='+databaseName+';UID='+username+';PWD='+ password
cnxn = pyodbc.connect(connection_string)
cursor = cnxn.cursor()

# %%
# Read data from SQL Server
df_SDIc = pd.read_sql_query("SELECT *  FROM dwh.vGHDX_Deaths_SDIcluster", con=cnxn)
df_Deaths = pd.read_sql_query("SELECT * FROM dwh.[vGHDX_Deaths]", con= cnxn)
df = pd.read_sql_query("select * from ml.Death_GHDX",con=cnxn)
# Out:
# C:\Users\IreneDeNevi\AppData\Local\Temp\ipykernel_15908\3043283878.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_SDIc = pd.read_sql_query("SELECT *  FROM dwh.vGHDX_Deaths_SDIcluster", con=cnxn)
# C:\Users\IreneDeNevi\AppData\Local\Temp\ipykernel_15908\3043283878.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_Deaths = pd.read_sql_query("SELECT * FROM dwh.[vGHDX_Deaths]", con= cnxn)
# C:\Users\IreneDeNevi\AppData\Local\Temp\ipykernel_15908\3043283878.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
df_SDIc
# Out:
#            SDI     sex                   Risk  year       val
# 0       Global    Male                Tobacco  1990  0.005892
# 1       Global    Male            Alcohol use  1990  0.034823
# 2       Global    Male          Dietary risks  1990  0.008466
# 3       Global    Male       All risk factors  1990  0.047415
# 4       Global  Female                Tobacco  1990  1.212533
# ...        ...     ...                    ...   ...       ...
# 2875  High SDI    Both            Alcohol use  2008  1.231895
# 2876  High SDI    Both        Metabolic risks  2008  1.242031
# 2877  High SDI    Both          Dietary risks  2008  0.471170
# 2878  High SDI    Both  Low physical activity  2008  0.155898
# 2879  High SDI    Both       All risk factors  2008  3.359447
#
# [2880 rows x 5 columns]

# %%
df_Deaths
# Out:
#       location   sex                   Risk  year       val
# 0        China  Both                Tobacco  1990  0.245127
# 1        China  Both            Alcohol use  1990  0.102353
# 2        China  Both        Metabolic risks  1990  0.484631
# 3        China  Both          Dietary risks  1990  0.144456
# 4        China  Both  Low physical activity  1990  0.045454
# ...        ...   ...                    ...   ...       ...
# 30595    Sudan  Both                Tobacco  2019  0.163817
# 30596    Sudan  Both            Alcohol use  2019  0.002127
# 30597    Sudan  Both        Metabolic risks  2019  0.712675
# 30598    Sudan  Both          Dietary risks  2019  0.107153
# 30599    Sudan  Both  Low physical activity  2019  0.233065
#
# [30600 rows x 5 columns]

# %%
df
# Out:
#       cluster_sdi                   Risk       Val location  year    SDI
# 0             Low                Tobacco  0.245127    China  1990  0.433
# 1             Low            Alcohol use  0.102353    China  1990  0.433
# 2             Low        Metabolic risks  0.484631    China  1990  0.433
# 3             Low          Dietary risks  0.144456    China  1990  0.433
# 4             Low  Low physical activity  0.045454    China  1990  0.433
# ...           ...                    ...       ...      ...   ...    ...
# 30895         Low                Tobacco  0.163817    Sudan  2019  0.515
# 30896         Low            Alcohol use  0.002127    Sudan  2019  0.515
# 30897         Low        Metabolic risks  0.712675    Sudan  2019  0.515
# 30898         Low          Dietary risks  0.107153    Sudan  2019  0.515
# 30899         Low  Low physical activity  0.233065    Sudan  2019  0.515
#
# [30900 rows x 6 columns]

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_SDIc, title="Report SDI")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-30 08:34:03.715538&quot;&gt;&lt;title&gt;Report SDI&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile = ProfileReport(df_Deaths, title="Report Deaths")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-30 08:34:11.220380&quot;&gt;&lt;title&gt;Report Deaths&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile = ProfileReport(df, title="Report DF used for ML")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-30 08:34:13.502078&quot;&gt;&lt;title&gt;Report DF used for ML&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
